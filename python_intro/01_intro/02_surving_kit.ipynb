# %% [markdown]
# ## Surviving kit
#  - `print`
#  - `type`
#  - `help`
#  - `dir`

# %%
print("hello", "world")

# %%
print(type("hello"))
print(type(1))
print(type(True))

# %%
help(1)

# %%
help(None)

# %%
IIII = 1
FFFF = 3.3
SSSS = 'cc'
BBBB = False

print(dir())

# %%
print(dir(1))
